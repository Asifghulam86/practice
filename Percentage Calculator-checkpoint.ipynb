# %%
# Percentage Calculator

# Getting user data input with welcome massage
first_name = input('Enter your first name: ')
last_name = input('Enter your last name: ')
full_name = (first_name + " " + last_name).title()
print('Welcome...! ' + full_name + '.')
print('Please input your mark obtained in following Subject: ')

# getting percentage calculator data from user
while True:
    try:
        Sindhi = int(input("Please enter your Sindhi marks : "))
    except ValueError:
        print("Sorry, I didn't understand that.")
        continue

    if Sindhi < 0:
        print("Sorry, your response must not be negative.")
    elif Sindhi > 100:
        print("Invalid input")
        continue
    else:
        break
        
while True:
    try:
        English = int(input("Please enter your English marks : "))
    except ValueError:
        print("Sorry, I didn't understand that.")
        continue

    if English < 0:
        print("Sorry, your response must not be negative.")
    elif English > 100:
        print("Invalid input")
        continue
    else:
        break
    
while True:
    try:
        Islamiat = int(input("Please enter your Islamiat marks : "))
    except ValueError:
        print("Sorry, I didn't understand that.")
        continue

    if Islamiat < 0:
        print("Sorry, your response must not be negative.")
    elif Islamiat > 100:
        print("Invalid input")
        continue
    else:
        break
            
while True:
    try:
        Urdu = int(input("Please enter your Urdu marks : "))
    except ValueError:
        print("Sorry, I didn't understand that.")
        continue

    if Urdu < 0:
        print("Sorry, your response must not be negative.")
    elif Urdu > 100:
        print("Invalid input")
        continue
    else:
        break
        
    
while True:
    try:
        Mathametics = int(input("Please enter your Mathametics marks : "))
    except ValueError:
        print("Sorry, I didn't understand that.")
        continue

    if Mathametics < 0:
        print("Sorry, your response must not be negative.")
    elif Mathametics > 100:
        print("Invalid input")
        continue
    else:
        break
    

        
#defining Variables for calculation and results:
#add subject followed by the 'Space' to calculating the percentage properly in variable Subject: 
Subjects = 'Sindhi English Urdu Islamiat Mathametics'
count = 1
for i in (Subjects):
    if i == " ":
        count += 1
        
total_marks = count * 100
obtained_marks = Sindhi + English + Urdu + Islamiat + Mathametics
percentage = round(int(obtained_marks)/total_marks*100)
failed = ("Dear " + full_name + " You have failed your exam achieving " + str(percentage) + "% marks. You must have failed in one or more paper. Try luck next time. Thank you :")
passed = ("Conratulation....! " + full_name + ". You have Achieved " + str(percentage) + "% in your Exams.")
fail = ('Your grade is "F".')




if Sindhi <= 39 or English <= 39 or Urdu <= 39 or Islamiat <= 39 or Mathametics <= 39 and percentage <= 39:
    result = failed
elif Sindhi <= 39 or English <= 39 or Urdu <= 39 or Islamiat <= 39 or Mathametics <= 39 and percentage >= 39:
    result = failed
else:
    Sindhi >= 39 and English >= 39 and Urdu >= 39 and Islamiat >= 39 and Mathametics >= 39
    result = passed

    
if result == passed and percentage >= 80:
    print("You have got A+ grade in your exam")
elif result == passed and percentage >= 70:
    print("You have got A grade in your exam")
elif result == passed and percentage >= 60:
    print("You have got B grade in your exam")
elif result == passed and percentage >= 50:
    print("You have got C grade in your exam")
elif result == passed and percentage >=40:
        print("You have got D grade in your exam")
else:
    result == failed
    print("You have got F grade in your exam")
        
print(result)
# Out:
# Enter your first name: fai
# Enter your last name: zan
# Welcome...! Fai Zan.
# Please input your mark obtained in following Subject:
# Please enter your Sindhi marks : 78
# Please enter your English marks : 89
# Please enter your Islamiat marks : 68
# Please enter your Urdu marks : 67
# Please enter your Mathametics marks : 67
# You have got A grade in your exam
# Conratulation....! Fai Zan. You have Achieved 74% in your Exams.
